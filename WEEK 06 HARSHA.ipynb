# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel(r"C:\Users\User\Downloads\Dataset_w6.xlsx")

# %%
data
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0              652864.0                         35530.0
# 1               28748.0                          2930.0
# 2             2381741.0                         41318.0
# ...

# %% [markdown]
# # 1.To find the number of countries in the dataset

# %%
data["country"].count()
# Out:
# 196

# %% [markdown]
# # 2.Data visualizations

# %%
plt.figure(figsize=(8,8))
sns.barplot(x='country',y='Population in thousands (2017)',data=data.sort_values('Population in thousands (2017)',ascending=False).head(10),color='purple')
plt.title('Top 10 countries based on Population in thousands (2017)',fontsize=16,fontweight='bold')
plt.xlabel('Country',fontsize=15)
plt.ylabel('Population in thousands (2017)',fontsize=14)
plt.xticks(rotation=90)
plt.grid(linestyle='--')
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.barplot(x='country',y='Agricultural production index ',data=data.sort_values('Agricultural production index ',ascending=True).head(10),color='blue')
plt.title('Least 10 countries based on Agricultural production index',fontsize=16,fontweight='bold')
plt.xlabel('Country',fontsize=15)
plt.ylabel('Agricultural production index',fontsize=14)
plt.xticks(rotation=90)
plt.grid(linestyle='--')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.bar(data['Region'], data['International trade: Imports (million US$)'])
plt.title('Region vs International trade: Imports (million US$)', fontweight='bold', fontsize=16,)
plt.xlabel('Region', fontweight='bold', fontsize=12)
plt.ylabel('International trade: Imports (million US$)', fontweight='bold', fontsize=12)
plt.xticks(rotation=90)
plt.grid(linestyle='--')
plt.show()

# %%
plt.hist(data['GDP per capita (current US$)'],rwidth=0.9,density=True)
plt.title('GDP per Capita',fontweight='bold',fontsize=18)
plt.xlabel('GDP per Capita')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # 3.Countries with respect to region available in the dataset

# %%
data.groupby("Region")[["country"]].count()
# Out:
#                    country
# Region
# Caribbean               16
# CentralAmerica           8
# CentralAsia              5
# EasternAfrica           17
# EasternAsia              7
# EasternEurope           10
# Melanesia                5
# Micronesia               4
# MiddleAfrica             9
# NorthernAfrica           5
# NorthernAmerica          4
# NorthernEurope          10
# Oceania                  2
# Polynesia                5
# South-easternAsia       11
# SouthAmerica            12
# SouthernAfrica           5
# SouthernAsia             9
# SouthernEurope          12
# WesternAfrica           15
# WesternAsia             18
# WesternEurope            7

# %% [markdown]
# # 4.On average which region has highest

# %% [markdown]
# # a.GDP per capita (current US$)

# %%
GDP=data.groupby("Region")[["GDP per capita (current US$)"]].mean()
GDP.sort_values(by="GDP per capita (current US$)",ascending=False)
# Out:
#                    GDP per capita (current US$)
# Region
# NorthernAmerica                    57659.000000
# WesternEurope                      55387.128571
# Oceania                            44823.250000
# NorthernEurope                     42098.220000
# EasternAsia                        27967.614286
# WesternAsia                        17013.938889
# Caribbean                          15135.562500
# SouthernEurope                     14462.741667
# South-easternAsia                  10299.027273
# EasternEurope                       9292.490000
# Melanesia                           9261.960000
# Polynesia                           8686.520000
# SouthAmerica                        8499.775000
# CentralAmerica                      6348.137500
# Micronesia                          5008.300000
# CentralAsia                         4329.880000
# SouthernAfrica                      4191.900000
# NorthernAfrica                      3934.960000
# ...

# %%
GDP.nlargest(1,"GDP per capita (current US$)")
# Out:
#                  GDP per capita (current US$)
# Region
# NorthernAmerica                       57659.0

# %%
#Northern America has the highest GDP per capita

# %% [markdown]
# # b.International trade:imports (million US$)

# %%
Imp=data.groupby("Region")[["International trade: Imports (million US$)"]].mean()
Imp.sort_values(by="International trade: Imports (million US$)",ascending=False)
# Out:
#                    International trade: Imports (million US$)
# Region
# NorthernAmerica                                 663552.250000
# EasternAsia                                     451995.000000
# WesternEurope                                   407498.428571
# NorthernEurope                                  113407.200000
# Oceania                                         112914.500000
# South-easternAsia                                98324.636364
# EasternEurope                                    85243.900000
# SouthernEurope                                   76666.666667
# SouthernAsia                                     58199.333333
# CentralAmerica                                   57031.500000
# WesternAsia                                      46025.555556
# NorthernAfrica                                   35034.400000
# SouthAmerica                                     32885.666667
# SouthernAfrica                                   18005.600000
# ...

# %%
Imp.nlargest(1,"International trade: Imports (million US$)")
# Out:
#                  International trade: Imports (million US$)
# Region
# NorthernAmerica                                   663552.25

# %%
#Northern America has the highest International trade:Imports

# %% [markdown]
# # 5.To find the region having more consistancy with respect to GDP per capita (current US$)

# %%
consis=data[['Region','GDP per capita (current US$)']].groupby(['Region']).agg('std')
consis
# Out:
#                    GDP per capita (current US$)
# Region
# Caribbean                          14579.371326
# CentralAmerica                      4180.440883
# CentralAsia                         4152.215490
# EasternAfrica                       3716.131770
# EasternAsia                        27485.120923
# EasternEurope                       5415.488739
# Melanesia                          13855.842686
# Micronesia                          4820.669694
# MiddleAfrica                        5274.846281
# NorthernAfrica                       974.706575
# NorthernAmerica                    25749.619445
# NorthernEurope                     20671.030185
# Oceania                             9233.329638
# Polynesia                           6956.250286
# South-easternAsia                  16311.810656
# SouthAmerica                        4273.707394
# SouthernAfrica                      2177.551120
# SouthernAsia                        2855.708179
# ...

# %%
consis[consis['GDP per capita (current US$)']==consis['GDP per capita (current US$)'].min()]
# Out:
#                GDP per capita (current US$)
# Region
# WesternAfrica                    815.095399
